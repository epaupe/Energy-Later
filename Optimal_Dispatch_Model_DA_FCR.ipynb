# %%
import numpy as np
import gurobipy as gp
from gurobipy import GRB
from gurobipy import quicksum
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import os

from functions import (plot_DA_week,
                    load_da_market_data,
                    load_fcr_prices,
                    plot_fcr_prices)

# %% [markdown]
# ## Parameters

# %% [markdown]
# #### Constants

# %%
#Battery Parameters
battery_capacity = 40 #[MWh]
SOC_min = 1 #[Mwh]
charge_rate_min = 0 #[MW]
discharge_rate_min = 0 #[MW]
charge_rate_max = 10 #[MW]
discharge_rate_max = 10 #[MW]
efficiency = 0.99
self_discharge_rate = 0
initial_SOC = 20 #[MWh]

#Market Parameters:
    #DAM:
minimum_bid_DAM = 0.1 #[MW]
granularity_DAM = 1 #hours

    #FCR:
minimum_bid_FCR = 1 #[MW]
granularity_FCR = 4 #hours
wcs_factor_FCR = [0.36, 0.27, 0.18, 0.9] #[MWh/MW]

# %% [markdown]
# #### Model Definitions

# %%
#Initialize optimization problem:
MMO = gp.Model("Multi Market Optimization")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2640286
# Academic license - for non-commercial use only - expires 2026-03-20

# %% [markdown]
# ## Data Loading

# %% [markdown]
# #### Day-Ahead Auction, (1h granularity)

# %%
da_folder = "data/energy-charts_day_ahead"
years_to_load = [2024] # Define the years you want to import, we have from 2015 to 2024.
DA_prices_merged = load_da_market_data(da_folder, years_to_load)
print(DA_prices_merged.head())

clearing_price_DAM = DA_prices_merged['price_eur_mwh'].to_numpy(dtype=float)
print(len(clearing_price_DAM))
timestamps = DA_prices_merged['timestamp']


bidding_slots_DAM = range(10) #arbitrary number for now, to allow for non-uniform biding
side = ["Buy","Sell"]

days = 365

DAM_horizon = range(int((24/granularity_DAM)) * (days +1))
print(len(DAM_horizon))
#NB: +1 because 2024 is a leap year(§366 days)
#DAM_horizon = range(len(clearing_price_DAM)) #Define the time horizon based on the length of the loaded data
#print(len(DAM_horizon))
# Out:
#                   timestamp  price_eur_mwh
# 0 2023-12-31 23:00:00+00:00          25.97
# 1 2024-01-01 00:00:00+00:00          21.99
# 2 2024-01-01 01:00:00+00:00          14.32
# 3 2024-01-01 02:00:00+00:00          11.37
# 4 2024-01-01 03:00:00+00:00          11.35
# 8784
# 8784

# %% [markdown]
# ##### Plotting

# %%
plot_DA_week(DA_prices_merged, year=2024, week=52) #Plot the DA prices for a given week

# %% [markdown]
# #### FCR Auction (4h Granularity)

# %%
fcr_folder = "data/Swissgrid_PRL_SRL_TRL"
years_to_load_FCR = [2024] # Define the years you want to import
merged_FCR = load_fcr_prices(fcr_folder, years_to_load_FCR)
print(merged_FCR.head()) #the timestamp indicate the hour at which the 4h block starts.
#print(merged_FCR.tail())
print(len(merged_FCR)) #NB: 2196 rows for 2024 (4h granularity), because 2024 is a leap year (366 days)

clearing_price_FCR = merged_FCR['Preis'].to_numpy(dtype=float)
print(len(clearing_price_FCR))

FCR_horizon = range(int((24/granularity_FCR) * (days+1)))
print(len(FCR_horizon))
# Out:
# Loaded and merged 1 FCR files (2196 total rows).
#             timestamp  Preis
# 0 2024-01-01 00:00:00   28.7
# 1 2024-01-01 04:00:00   26.1
# 2 2024-01-01 08:00:00   17.2
# 3 2024-01-01 12:00:00   19.4
# 4 2024-01-01 16:00:00   18.1
# 2196
# 2196
# 2196

# %% [markdown]
# ##### Plotting

# %%
plot_fcr_prices(merged_FCR, year=2024, week=52) #Plot the FCR prices for a given week
plot_fcr_prices(merged_FCR, year=2024) #Plot the FCR prices for the whole year

# %% [markdown]
# ## Decision Variables

# %%
# BESS Variables
Charge = MMO.addVars(DAM_horizon, vtype=GRB.CONTINUOUS, lb=charge_rate_min, ub=charge_rate_max, name="Battery_Charge [MW]") 
Discharge = MMO.addVars(DAM_horizon, vtype=GRB.CONTINUOUS, lb=discharge_rate_min, ub=discharge_rate_max, name="Battery_Discharge [MW]")
Charging_Indicator = MMO.addVars(DAM_horizon, vtype=GRB.BINARY, name= "Charging_Indicator") #1 if charging, 0 if discharging

SOC = MMO.addVars(DAM_horizon, vtype=GRB.CONTINUOUS, lb=SOC_min, ub=battery_capacity, name="Battery_State_Of_Charge [MWh]") 

#Day Ahead Variables
DAM_Bid_Price = MMO.addVars(DAM_horizon, bidding_slots_DAM, side, vtype=GRB.CONTINUOUS, lb=0, name="Day_Ahead_Market_Bid [CHF]")
DAM_Bid_Volume = MMO.addVars(DAM_horizon, bidding_slots_DAM, side, vtype=GRB.CONTINUOUS, lb=0, name="Day_Ahead_Market_Volume [#MW]")
DAM_Bid_Placement = MMO.addVars(DAM_horizon, bidding_slots_DAM, side, vtype=GRB.BINARY, name="Day_Ahead_Market_Bid_Placement")

DAM_Bid_Activation = MMO.addVars(DAM_horizon, bidding_slots_DAM, side, vtype=GRB.BINARY, name="Day_Ahead_Market_Bid_Acceptance")
DAM_Executed_volume = MMO.addVars(DAM_horizon, bidding_slots_DAM, side, vtype=GRB.CONTINUOUS, lb=0, name="Day_Ahead_Market_Executed_Volume [MW]")

#FCR Market Variables
FCR_Participation = MMO.addVars(FCR_horizon, vtype=GRB.BINARY, name="FCR_Market_Participation") #1 if participating in FCR market at time t, 0 otherwise
FCR_Volume = MMO.addVars(FCR_horizon, vtype=GRB.CONTINUOUS, lb=0, ub=charge_rate_max, name="FCR_Volume [MW]") #Volume of FCR offered at time t

# %% [markdown]
# ## Constraints

# %%
#1 - Battery State of Charge Balance 
MMO.addConstr(SOC[0] == initial_SOC)
MMO.addConstr(SOC[max(DAM_horizon)] == initial_SOC) #End the horizon at initial SOC

for t in DAM_horizon[:-1]:
    MMO.addConstr(SOC[t+1] == (1 - self_discharge_rate) * SOC[t] + granularity_DAM * (efficiency * Charge[t] - 1 / efficiency * Discharge[t])) #SOC balance equation

#2 - Day Ahead Market Constraints
for t in DAM_horizon:
    for slot in bidding_slots_DAM:
        #Cannot buy and sell simultaniously in the same bidding slot 
        MMO.addConstr(DAM_Bid_Placement[t, slot, "Buy"] + DAM_Bid_Placement[t, slot, "Sell"] <= 1)
    
        #Market Clearing
        MMO.addGenConstrIndicator(DAM_Bid_Activation[t, slot, "Buy"], True, DAM_Bid_Price[t , slot, "Buy"] >= clearing_price_DAM[t])
        MMO.addGenConstrIndicator(DAM_Bid_Activation[t, slot, "Buy"], False, DAM_Bid_Price[t , slot, "Buy"] <= clearing_price_DAM[t])
        MMO.addConstr(DAM_Bid_Activation[t, slot, "Buy"] <= DAM_Bid_Placement[t, slot, "Buy"])

        MMO.addGenConstrIndicator(DAM_Bid_Activation[t, slot, "Sell"], False, DAM_Bid_Price[t, slot, "Sell"] >= clearing_price_DAM[t])
        MMO.addGenConstrIndicator(DAM_Bid_Activation[t, slot, "Sell"], True, DAM_Bid_Price[t, slot, "Sell"] <= clearing_price_DAM[t])
        MMO.addConstr(DAM_Bid_Activation[t, slot, "Sell"] <= DAM_Bid_Placement[t, slot, "Sell"])

        for s in side:
            #Enfore minimum bidding volume
            MMO.addConstr(DAM_Bid_Placement[t, slot, s] * minimum_bid_DAM <= DAM_Bid_Volume[t, slot, s])
            #Extract Executed Volume 
            MMO.addGenConstrIndicator(DAM_Bid_Activation[t, slot, s], True, DAM_Executed_volume[t, slot, s] == DAM_Bid_Volume[t, slot, s])
            MMO.addGenConstrIndicator(DAM_Bid_Activation[t, slot, s], False, DAM_Executed_volume[t, slot, s] == 0)

#3 - FCR Market constraints
for t in FCR_horizon:
    MMO.addConstr(FCR_Participation[t] * minimum_bid_FCR <= FCR_Volume[t])# Ensure minimum bid volume if participating in FCR market
    for j in range(granularity_FCR):
       MMO.addConstr(SOC[granularity_FCR * t + j] >= FCR_Volume[t] * wcs_factor_FCR[j] + SOC_min) # Ensure minimum SoC constraint for FCR provision
       MMO.addConstr(SOC[granularity_FCR * t + j] <= battery_capacity - FCR_Volume[t] * wcs_factor_FCR[j]) # Ensure maximum SoC constraint for FCR provision
       
       # Power headroom so you can still deliver ±FCR while charging/discharging
       MMO.addConstr(Discharge[granularity_FCR * t + j] + FCR_Volume[t] <= discharge_rate_max) 
       MMO.addConstr(Charge[granularity_FCR * t + j]    + FCR_Volume[t] <= charge_rate_max)

for t in DAM_horizon:
    #Link the executed bids to the battery dispatch
    MMO.addConstr(Discharge[t] == quicksum(DAM_Executed_volume[t, slot, "Sell"] for slot in bidding_slots_DAM))
    MMO.addConstr(Charge[t] == quicksum(DAM_Executed_volume[t, slot, "Buy"] for slot in bidding_slots_DAM))

    #Prevent simultanious charging and discharging
    MMO.addGenConstrIndicator(Charging_Indicator[t], True,  Discharge[t] == 0)
    MMO.addGenConstrIndicator(Charging_Indicator[t], False,  Charge[t] == 0)

max_daily_cycles = 2
avg_agg_FCR_discharge = 0.136

for d in range(days + 1):
    MMO.addConstr(quicksum(Discharge[24//granularity_DAM * d + t] for t in range(24//granularity_DAM)) 
                  + quicksum(avg_agg_FCR_discharge * FCR_Volume[24//granularity_FCR * d + t] for t in range(24//granularity_FCR)) 
                  <= max_daily_cycles * battery_capacity)

# %% [markdown]
# ## Objective Function & Solving

# %%
# DA term : €/MWh × (MW × h) = € 
DA_term  = quicksum(clearing_price_DAM[t] * (Discharge[t] - Charge[t]) * granularity_DAM
                    for t in DAM_horizon)

# FCR term for €/MWh: multiply by energy of the block (MW × 4 h)
FCR_term = quicksum(FCR_Volume[t] * clearing_price_FCR[t]
                    for t in FCR_horizon)

Profit = DA_term + FCR_term


#Solve Optimization Problem
MMO.setObjective(Profit, GRB.MAXIMIZE)
MMO.setParam('TimeLimit', 5 * 60) 
MMO.optimize()
# Out:
# Set parameter TimeLimit to value 300
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  300
#
# Optimize a model with 2011906 rows, 917928 columns and 4736764 nonzeros
# Model fingerprint: 0x344cb210
# Model has 2881152 simple general constraints
#   2881152 INDICATOR
# Variable types: 555588 continuous, 362340 integer (362340 binary)
# Coefficient statistics:
#   Matrix range     [1e-01, 1e+00]
#   Objective range  [1e-02, 4e+02]
#   Bounds range     [1e+00, 4e+01]
#   RHS range        [1e+00, 8e+01]
#   GenCon rhs range [1e-02, 4e+02]
#   GenCon coe range [1e+00, 1e+00]
#
# Processing MIP start from previous solve: 0 nodes explored in subMIP, total elapsed time 5s
# Processing MIP start from previous solve: 0 nodes explored in subMIP, total elapsed time 13s
# Processing MIP start from previous solve: 0 nodes explored in subMIP, total elapsed time 15s
# MIP start from previous solve produced solution with objective 767246 (18.85s)
# Loaded MIP start from previous solve with objective 767246
# Processed MIP start in 20.18 seconds (5.78 work units)
#
# Presolve removed 1543201 rows and 11018 columns (presolve time = 6s)...
# Presolve removed 3279263 rows and 564480 columns (presolve time = 11s)...
# Presolve added 1812377 rows and 2360688 columns
# Presolve time: 11.42s
# Presolved: 3824283 rows, 3278616 columns, 7983890 nonzeros
# Presolved model has 691040 SOS constraint(s)
# Variable types: 906944 continuous, 2371672 integer (2371672 binary)
# Performing another presolve...
# Presolve removed 2812832 rows and 2223064 columns (presolve time = 5s)...
# Presolve removed 2812860 rows and 2223082 columns (presolve time = 10s)...
# Presolve removed 2812860 rows and 2223082 columns
# Presolve time: 14.72s
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.09s
#
# Barrier statistics:
#  AA' NZ     : 3.932e+05
#  Factor NZ  : 6.933e+05 (roughly 40 MB of memory)
#  Factor Ops : 1.074e+07 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -2.58226367e+07  1.54620662e+06  2.50e+02 7.72e+02  1.13e+04    68s
#    1  -9.68192967e+06  7.09071464e+07  8.60e+01 1.18e+02  3.35e+03    68s
#    2  -2.46184907e+05  3.97202522e+07  1.54e+00 1.59e-12  4.31e+02    69s
#    3   1.74892508e+05  6.38176105e+06  1.88e-03 1.02e-12  5.95e+01    69s
#    4   4.01416199e+05  2.27418573e+06  6.20e-04 4.55e-13  1.80e+01    69s
#    5   6.76608620e+05  1.48688655e+06  1.80e-04 4.69e-13  7.77e+00    69s
#    6   7.99126799e+05  1.18747966e+06  5.57e-05 4.62e-13  3.72e+00    69s
#    7   8.40010893e+05  1.08320943e+06  3.01e-05 4.55e-13  2.33e+00    69s
#    8   8.65062044e+05  1.00178961e+06  1.63e-05 4.55e-13  1.31e+00    69s
#    9   8.80123596e+05  9.64777405e+05  8.89e-06 4.83e-13  8.12e-01    69s
#   10   8.90291599e+05  9.30910727e+05  4.23e-06 4.26e-13  3.89e-01    69s
#   11   8.96769047e+05  9.17902126e+05  1.47e-06 6.20e-13  2.03e-01    69s
#   12   8.99839011e+05  9.08063612e+05  3.41e-07 5.03e-13  7.89e-02    69s
#   13   9.00615664e+05  9.03767992e+05  1.23e-07 4.67e-13  3.02e-02    69s
#   14   9.00893874e+05  9.02282471e+05  6.01e-08 4.97e-13  1.33e-02    69s
#   15   9.01107662e+05  9.01543939e+05  1.41e-08 5.12e-13  4.18e-03    69s
#   16   9.01167557e+05  9.01305949e+05  2.83e-09 5.00e-13  1.33e-03    69s
#   17   9.01184019e+05  9.01214301e+05  4.68e-10 4.94e-13  2.90e-04    69s
#   18   9.01188121e+05  9.01191438e+05  4.78e-11 5.24e-13  3.18e-05    69s
#   19   9.01188797e+05  9.01188855e+05  2.18e-11 5.21e-13  5.54e-07    69s
#   20   9.01188833e+05  9.01188833e+05  3.66e-10 6.82e-13  8.18e-10    69s
#   21   9.01188833e+05  9.01188833e+05  1.44e-10 4.83e-13  8.32e-13    70s
#
# Barrier solved model in 21 iterations and 69.53 seconds (38.05 work units)
# Optimal objective 9.01188833e+05
#
#
# Root crossover log...
#
#     9453 DPushes remaining with DInf 0.0000000e+00                70s
#        0 DPushes remaining with DInf 0.0000000e+00                70s
#
#      879 PPushes remaining with PInf 0.0000000e+00                70s
#        0 PPushes remaining with PInf 0.0000000e+00                70s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.2923545e-10     70s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5228    9.0118883e+05   0.000000e+00   0.000000e+00     70s
#     5228    9.0118883e+05   0.000000e+00   0.000000e+00     70s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#    44157 DPushes remaining with DInf 0.0000000e+00                70s
#        0 DPushes remaining with DInf 0.0000000e+00                70s
#
#    46675 PPushes remaining with PInf 0.0000000e+00                71s
#        0 PPushes remaining with PInf 0.0000000e+00                71s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.8715988e-11     71s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    55572    9.0118883e+05   0.000000e+00   0.000000e+00     71s
#    55780    9.0118883e+05   0.000000e+00   0.000000e+00     72s
# Extra simplex iterations after uncrush: 208
# Concurrent spin time: 0.86s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root relaxation: objective 9.011888e+05, 82426 iterations, 8.54 seconds (2.96 work units)
# Total elapsed time = 72.91s (DegenMoves)
# Total elapsed time = 79.14s (DegenMoves)
# Total elapsed time = 81.06s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 901188.833    0 307104 767246.132 901188.833  17.5%     -   84s
# H    0     0                    862750.83751 901188.833  4.46%     -   86s
#      0     0 901188.833    0 307110 862750.838 901188.833  4.46%     -  101s
#      0     0 901188.833    0 307100 862750.838 901188.833  4.46%     -  111s
#      0     0 901188.833    0 307106 862750.838 901188.833  4.46%     -  119s
#      0     0 901188.833    0 307096 862750.838 901188.833  4.46%     -  122s
# H    0     0                    862791.48051 901188.833  4.45%     -  124s
# H    0     0                    866252.90911 901188.833  4.03%     -  125s
#      0     0 901188.833    0 307096 866252.909 901188.833  4.03%     -  146s
# H    0     0                    866253.35996 901188.833  4.03%     -  156s
# H    0     0                    867188.72958 901188.833  3.92%     -  157s
# H    0     0                    867544.84162 901188.833  3.88%     -  163s
# H    0     0                    867716.85862 901188.833  3.86%     -  178s
# H    0     0                    867755.16018 901188.833  3.85%     -  178s
# H    0     0                    867756.02404 901188.833  3.85%     -  179s
# H    0     0                    867756.90714 901188.833  3.85%     -  179s
#      0     2 901188.833    0 307096 867756.907 901188.833  3.85%     -  182s
#      1     4 901188.833    1 307092 867756.907 901188.833  3.85%   0.0  197s
#      3     8 901188.833    2 307088 867756.907 901188.833  3.85%   0.7  200s
#      7    14 901188.833    3 307084 867756.907 901188.833  3.85%   0.9  205s
#     13    34 901188.833    4 307080 867756.907 901188.833  3.85%   0.8  211s
#     33    53 901188.255    6 307066 867756.907 901188.833  3.85%   0.6  228s
# H   44    53                    869797.03643 901188.833  3.61%   0.6  228s
#     52   108 901188.255    8 307058 869797.036 901188.833  3.61%   0.6  247s
#    107   191 901188.833   12 307048 869797.036 901188.833  3.61%   0.8  281s
#    190   209 901188.255   19 307022 869797.036 901188.833  3.61%   1.2  302s
# H  191   209                    870204.66386 901188.833  3.56%   1.2  302s
#
# Cutting planes:
#   Implied bound: 8
#
# Explored 208 nodes (136578 simplex iterations) in 305.09 seconds (145.22 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 870205 869797 867757 ... 866253
#
# Time limit reached
# Best objective 8.702046638634e+05, best bound 9.011888330380e+05, gap 3.5606%

# %% [markdown]
# ## Extract Results

# %%
print(f"Maximum Profit: {MMO.ObjVal:.2f} €")
Charge_opt = np.array([Charge[t].X for t in DAM_horizon])
Discharge_opt = np.array([Discharge[t].X for t in DAM_horizon])
SOC_opt = np.array([SOC[t].X for t in DAM_horizon])
FCR_block_opt = np.array([FCR_Volume[t].X for t in FCR_horizon])

# FCR results (4h blocks) → hourly series
# Out:
# Maximum Profit: 870204.66 €

# %%
# -------------------------------
# Plot optimal schedule and prices
# -------------------------------
week_number = 20  # Choose the week (1 = first week, etc.)
hours_per_week = 24 * 7
start_idx = (week_number - 1) * hours_per_week
end_idx = start_idx + hours_per_week

time_week = timestamps.iloc[start_idx:end_idx]
Charge_week = Charge_opt[start_idx:end_idx]
Discharge_week = Discharge_opt[start_idx:end_idx]
SOC_week = SOC_opt[start_idx:end_idx]
Price_week = clearing_price_DAM[start_idx:end_idx]

FCR_price_hourly = np.repeat(clearing_price_FCR, granularity_FCR)
FCR_price_hourly = FCR_price_hourly[:len(timestamps)]  # align lengths
FCR_price_week   = FCR_price_hourly[start_idx:end_idx]


FCR_hourly    = np.repeat(FCR_block_opt, granularity_FCR)
FCR_hourly    = FCR_hourly[:len(Charge_opt)]  # align lengths
FCR_week      = FCR_hourly[start_idx:end_idx]

fig, axs = plt.subplots(2, 1, figsize=(14, 8), sharex=True, gridspec_kw={'height_ratios': [2, 1]})

# --- Plot 1: Battery operation ---
axs[0].fill_between(time_week, 0, Charge_week, step='post', alpha=0.4, color='blue', label='Charge [MW]')
axs[0].fill_between(time_week, 0, -Discharge_week, step='post', alpha=0.4, color='red', label='Discharge [MW]')
axs[0].fill_between(time_week, 0, FCR_week, step='post', alpha=0.15, color='purple')
axs[0].plot(time_week, SOC_week, color='black', linewidth=2, label='SOC [MWh]')
axs[0].set_ylabel("Power [MW] / SoC [MWh]")
axs[0].grid(True)
axs[0].set_title(f"Optimal BESS Schedule — Week {week_number} ({timestamps.dt.year.iloc[1]})")
axs[0].step(time_week, FCR_week, where='post', color='purple', linewidth=1.6, label='FCR Reserve [MW]')
axs[0].legend(loc='upper left')

# --- Plot 2: DA Prices ---
axs[1].plot(time_week, Price_week, color='green', linewidth=1.8)
axs[1].set_ylabel("DA Price [€/MWh]")
axs[1].grid(True)
axs[1].set_xlabel("Time [UTC]")
axs[1].step(time_week, FCR_price_week, where='post',
            color='purple', linewidth=1.6, label='FCR Price')
axs[1].legend(loc='upper left')
plt.tight_layout()
plt.show()
